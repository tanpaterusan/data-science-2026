# %% [markdown]
# <a href="https://colab.research.google.com/github/tanpaterusan/data-science-2026/blob/main/Pertemuan1_Amalia_240401010284.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
# SEL 2: Variabel & tipe data
nama     = "Mahasiswa Informatika"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Mahasiswa Informatika angkatan 2024!

# %%
# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub

# %%
# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Budi","Informatika","2024"))
# Out:
# Budi | Informatika | 2024

# %% [markdown]
# **Evaluasi**
#
# 1. Apa yang Saya Pelajari
# - Sintaks Dasar Python: Cara menampilkan teks ke layar menggunakan print() dan memformat teks secara dinamis dengan f-string.
# - Struktur Data List: Menyimpan sekumpulan data teks (koleksi tools) dalam satu variabel bertipe List.
# - Perulangan Pintar: Menggunakan for dan enumerate() untuk memunculkan isi list sekaligus membuat nomor urutnya secara otomatis.
# - Modularitas Fungsi: Membuat fungsi kustom dengan perintah def dan return agar kode bisa digunakan berulang kali dengan input berbeda.
#
#
# ---
#
#
# 2. Temuan Utama Data
# - Efisiensi Loop: Fungsi enumerate(tools, 1) terbukti sangat praktis karena kita tidak perlu membuat variabel penghitung manual ($i = i + 1$) untuk penomoran.
# - Fleksibilitas F-String: Penulisan gabungan teks dan variabel jauh lebih bersih dan rapi menggunakan struktur f"{variabel}" dibanding menggabungkannya dengan simbol tambah (+).
# - Sifat Reusable Fungsi: Fungsi perkenalan sukses menyatukan tiga parameter masukan (nama, prodi, angkatan) menjadi satu baris teks ringkas yang terstandarisasi.
#
#
# ---
#
#
# 3. Keterbatasan & Pertanyaan Belajar
# - Variabel Statis: Data nama, prodi, dan angkatan masih ditulis manual keras (hardcoded) di dalam script. Bagaimana cara membuatnya dinamis agar bisa menerima ketikan langsung dari pengguna (user input)?
# - Tanpa Validasi Tipe Data: Fungsi perkenalan tidak membatasi tipe data masukan. Apa yang terjadi jika parameter angkatan diisi teks acak atau parameter nama diisi angka? Apakah kodenya akan error?
# - Keterbatasan List Sederhana: Struktur data List di Sel 3 hanya bisa menampung nama tools. Jika kita ingin menyimpan fungsi dari masing-masing tool tersebut, apakah sebaiknya kita mengganti strukturnya menggunakan Dictionary (Key-Value)?
